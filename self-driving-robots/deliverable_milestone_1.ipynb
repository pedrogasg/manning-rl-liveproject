# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrogasg/manning-rl-liveproject/blob/master/self-driving-robots/deliverable_milestone_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install cmake 'gym[atari]' scipy  > /dev/null 2>&1

# %%
import gym
env = gym.make("Taxi-v3")
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# Action Space Discrete(6)
# State Space Discrete(500)

# %%
from IPython.display import clear_output

done = False
env.reset()
while not done:
  clear_output(wait=True)
  action = env.action_space.sample()
  state, reward, done, info = env.step(action)
  env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)

# %%
import numpy as np
import matplotlib.pyplot as plt

done = False
rewards = []
env.reset()
while not done:
  clear_output(wait=True)
  action = env.action_space.sample()
  state, reward, done, info = env.step(action)
  rewards.append(reward)
  env.render()

x = np.arange(len(rewards))
plt.plot(x, rewards, label='Rewards')
# Out:
# +---------+
# |R: | : :G|
# | :_| : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)

# %%
numEpisodes = 10
average_rewards = []
for i in range(numEpisodes):
  done = False
  rewards = []
  env.reset()
  while not done:
    clear_output(wait=True)
    action = env.action_space.sample()
    state, reward, done, info = env.step(action)
    rewards.append(reward)
    env.render()
  average_reward = (sum(rewards)/len(rewards))
  average_rewards.append(average_reward)


x = np.arange(len(average_rewards))
plt.plot(x, average_rewards, label='Averages Rewards')
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (Dropoff)

# %%
env = gym.make("Pendulum-v0")

# %%
print("Action Space {}".format(env.action_space))
print("State Space {}".format(env.observation_space))
# Out:
# Action Space Box(-2.0, 2.0, (1,), float32)
# State Space Box(-8.0, 8.0, (3,), float32)

# %%
done = False
env.reset()
while not done:
  action = env.action_space.sample()
  state, reward, done, info = env.step(action)

# %%
import numpy as np
import matplotlib.pyplot as plt

done = False
rewards = []
env.reset()
while not done:
  action = env.action_space.sample()
  state, reward, done, info = env.step(action)
  rewards.append(reward)

x = np.arange(len(rewards))
plt.plot(x, rewards, label='Rewards')

# %%
numEpisodes = 10
average_rewards = []
for i in range(numEpisodes):
  done = False
  rewards = []
  env.reset()
  while not done:
    action = env.action_space.sample()
    state, reward, done, info = env.step(action)
    rewards.append(reward)
  average_reward = (sum(rewards)/len(rewards))
  average_rewards.append(average_reward)


x = np.arange(len(average_rewards))
plt.plot(x, average_rewards, label='Averages Rewards')
